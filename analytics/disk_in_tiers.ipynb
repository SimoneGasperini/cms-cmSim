# %%
import pandas as pd

df = pd.read_parquet('../data/parquet/dataset_site_info.parquet')

df = df.drop(columns=['dataset_id', 'replica_time_create', 'br_user_group_id'])
df = df.dropna()

for word in ['BUNNIES', 'Commissioning', 'RelVal']:
    df = df[~df['dataset_name'].str.contains(word)]

df.head(None)
# Out:
#                                               dataset_name          node_name  \
# 0                     /JetHT/Run2016B-23Sep2016-v1/MINIAOD    T1_RU_JINR_Disk
# 1        /QCD_Pt_120to170_TuneCP5_13TeV_pythia8/RunIISu...         T2_IN_TIFR
# 2        /EGamma/Run2018A-EcalUncalZElectron-12Nov2019_...         T2_IN_TIFR
# 3        /QCD_HT1500to2000_TuneCP5_PSWeights_13TeV-madg...    T1_US_FNAL_Disk
# 4        /QCD_Pt_50to80_TuneCUETP8M1_13TeV_pythia8/RunI...         T2_CH_CERN
# ...                                                    ...                ...
# 6752625  /WZTo3LNu_mllmin01_NNPDF31_TuneCP5_13TeV_powhe...  T2_UK_SGrid_RALPP
# 6752626  /SMS-T1qqqq_mGluino-1400_mLSP-100_TuneCUETP8M1...      T2_EE_Estonia
# 6752627        /HIDoubleMuon/HIRun2018A-04Apr2019-v1/DQMIO     T1_DE_KIT_Disk
# 6752628  /SMS-T5qqqqHg_refPoints_TuneCP2_13TeV-madgraph...    T1_IT_CNAF_Disk
# 6752629  /GluGluToHiggs0PL1continToZZTo4e_M125_GaSM_Tun...     T2_US_Nebraska
#
# ...

# %%
from cmSim.container import DataContainer
from cmSim import utils

real = df[df['tier'].isin(utils.get_datatiers(type='data'))]
datatiers = ['RAW', 'RECO', 'AOD', 'ALCARECO', 'PREMIX', 'MINIAOD']
real_data = DataContainer.from_dataframe(real)

# %%
import pylab as plt

fig, ax = plt.subplots(figsize=(16, 12))
real_data.plot_storage_history_by_datatier(
    ax, datatiers, date1='2019-01-01', date2='2020-10-31', freq='W', tier='T1')
ax.set_title('Tier-1', fontsize=34)
fig.set_facecolor('white')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 12))
real_data.plot_storage_history_by_datatier(
    ax, datatiers, date1='2019-01-01', date2='2020-10-31', freq='W', tier='T2')
ax.set_title('Tier-2', fontsize=34)
fig.set_facecolor('white')

plt.show()

# %%
sim = df[df['tier'].isin(utils.get_datatiers(type='mc'))]
datatiers = ['AODSIM', 'GEN-SIM', 'GEN-SIM-RECO', 'GEN-SIM-DIGI-RAW', 'GEN-SIM-RAW', 'MINIAODSIM']
sim_data = DataContainer.from_dataframe(sim)

# %%
fig, ax = plt.subplots(figsize=(16, 12))
sim_data.plot_storage_history_by_datatier(
    ax, datatiers, date1='2019-01-01', date2='2020-10-31', freq='W', tier='T1', norm=False)
ax.set_title('Tier-1', fontsize=34)
fig.set_facecolor('white')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 12))
sim_data.plot_storage_history_by_datatier(
    ax, datatiers, date1='2019-01-01', date2='2020-10-31', freq='W', tier='T2', norm=False)
ax.set_title('Tier-2', fontsize=34)
fig.set_facecolor('white')

plt.show()

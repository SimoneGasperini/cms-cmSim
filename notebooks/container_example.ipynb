# %%
import pandas as pd

df = pd.read_parquet('./../data/dataset_site_info.parquet')

# %%
from cmSim.utils import get_mcm_data

mcm_data = get_mcm_data('./../data/zip_mcm_dump.json')
# Out:
# Unzipping and loading json file... Done

# %%
from cmSim.utils import get_pwg_from_dataset

df['pwg'] = df['dataset_name'].apply(get_pwg_from_dataset, mcm_data=mcm_data)

df.head(None)
# Out:
#                                               dataset_name  dataset_id  \
# 0        /JetHT/Run2016B-21Feb2020_ver2_UL2016_HIPM-v1/AOD     1553410
# 1             /PAMinimumBias4/PARun2016C-PromptReco-v1/AOD      951505
# 2        /GluGluToContinToZZTo2mu2nu_13TeV_MCFM701_pyth...     1114967
# 3        /WJetsToLNu_HT-70To100_TuneCP5_13TeV-madgraphM...     1247050
# 4          /HLTPhysics/Commissioning2017-PromptReco-v1/AOD      998897
# ...                                                    ...         ...
# 1268205  /GluGluHToWWToLNuQQ_M140_NNPDF31_TuneCP5_PSwei...     1353747
# 1268206  /ggZH_HToGG_ZToNuNu_M125_13TeV_powheg_pythia8_...     1307530
# 1268207  /ST_tW_top_5f_NoFullyHadronicDecays_13TeV_PSwe...     1332017
# 1268208  /GJet_Pt-20to40_DoubleEMEnriched_MGG-80toInf_T...     1573739
# 1268209  /GluGluHToWWToLNuQQ_M1500_13TeV_powheg2_JHUGen...     1282987
#
#         replica_time_create          node_name      rep_size    min_time  \
# ...

# %%
from cmSim.container import get_datasets, DataContainer

datasets = get_datasets(df, pwg='HIG', datatier='AODSIM')
container = DataContainer.from_dataframe(datasets=datasets, df=df)

# %%
import pylab as plt

fig, ax = plt.subplots(figsize=(16, 10))
container.plot_storage_history_in_datalakes(ax, tier='T1')
# Out:
# c:\users\simon\desktop\master_thesis\repos\cms-cmsim\cmSim\container.py:108: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datalake'] = df['node_name'].apply(utils.get_datalake_from_site)

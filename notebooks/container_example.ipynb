# %%
import pandas as pd

df = pd.read_parquet('./../data/aod_data_history.parquet')
df.head(None)
# Out:
#                                               dataset_name  dataset_id  \
# 8        /Dijet_pThat-30_pPb-Bst_8p16_Pythia8/pPb816Sum...     1026084
# 22       /BdToJpsiKs_SoftQCDnonD_TuneCP5_13TeV-pythia8-...     1580687
# 32       /JpsiMM_5p02TeV_TuneCUETP8M1/HINppWinter16DR-7...      908169
# 53       /UpsilonToTauTau_MuFilter_SoftQCDnonD_TuneCP5_...     1507811
# 54       /SingleElectron/Run2016B-21Feb2020_ver2_UL2016...     1539121
# ...                                                    ...         ...
# 6752616  /ZeroBias7/Run2017C-09Aug2019_UL2017_LowPU-v1/AOD     1569018
# 6752619  /SeesawTypeIII_M-700_2e_13TeV-TuneCP5-madgraph...     1576556
# 6752620  /QstarToGJ_M-8000_f-0p1_TuneCP2_13TeV-pythia8/...     1401295
# 6752622  /EWK_LLJJ_MLL_105-160_SM_5f_LO_TuneCP5_PSweigh...     1366906
# 6752625  /WZTo3LNu_mllmin01_NNPDF31_TuneCP5_13TeV_powhe...     1258355
#
#         replica_time_create          node_name      rep_size    min_time  \
# ...

# %%
from cmSim.container import get_datasets, DataContainer

datasets = get_datasets(df, pwgs=['HIG'], datatiers=['AODSIM'])
container = DataContainer.from_dataframe(df, datasets=datasets)

# %%
import pylab as plt

fig, ax = plt.subplots(figsize=(16, 12))
container.plot_storage_history_in_sites(ax, tier='T2', norm=True)

# %%
fig, ax = plt.subplots(figsize=(16, 12))
container.plot_storage_history_in_countries(ax, norm=True)

# %%
fig, ax = plt.subplots(figsize=(16, 12))
container.plot_storage_history_in_datalakes(ax, norm=False)
